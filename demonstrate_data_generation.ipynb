# %%
from utils import generate_data
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,4)

# %%
# variables inside of `data`
data = generate_data()
[x for x in dir(data) if "__" not in x]
# Out:
# ['alpha', 'beta', 'days', 'mu', 'sigma', 'x', 'x_df', 'y', 'z']

# %%
# Coefficients for variance function
data.alpha
# Out:
# array([-1.  , -0.2 , -0.03, -0.3 ,  0.03,  0.06,  0.1 ,  0.09, -0.04,
#        -0.23,  0.16, -0.05])

# %%
# Coefficients for mean fucntion
data.beta
# Out:
# array([ 5.  ,  0.4 , -0.17, -0.3 ,  0.03,  0.06,  0.1 ,  0.09, -0.04,
#        -0.23,  0.2 , -0.1 ])

# %%
# Raw data over time
data = generate_data()
plt.plot(data.days, data.y)
plt.show()

# %%
# Change in mean funtion over time
plt.plot(data.days, data.mu)
plt.show()

# %%
# Change in variance function over time
# Comparing to the plot above, you can see that the model has a
plt.plot(data.days, data.sigma**2)
plt.show()
